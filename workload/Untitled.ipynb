# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
breakpoints = [
    (0, 20),
    (8, 80),
    (12, 50),
    (17, 100),
    (24, 20),
]

# %%
def create_cycle(bpts):
    container = []
    
    for current in range(len(bpts) - 1):
        next = current+1
        
        first = bpts[current]
        second = bpts[next]
        
        points = np.linspace(first[1], second[1], abs(first[0] - second[0]) + 1)
        container.extend(points[:-1])
        
        #if (next+1) == len(bpts):
        #    container.append(points[-1])
    
    #container[-1] = bpts[-1][1]
    
    labels = [x for x in range(len(container))]
    
    return labels, container

# %%
len(dataset)
# Out:
# 24

# %%
labels, dataset = create_cycle(breakpoints)

# Fit a polynomial of degree 3 (you can change the degree for different levels of smoothing)
coefficients = np.polyfit(labels, dataset, 8)
polynomial = np.poly1d(coefficients)

# Generate more points for a smoother curve
x_smooth = np.linspace(0, len(labels), 200)  # 100 points between 0 and 1 for a smooth curve
y_smooth = polynomial(x_smooth)

# Plot the smooth curve
plt.plot(x_smooth, y_smooth, label='Smooth Curve')

# %%
y_smooth
# Out:
# array([18.16654188, 21.80600913, 24.75474236, 27.10745061, 28.95062139,
#        30.36299068, 31.41599515, 32.17420746, 32.69575467, 33.03272036,
#        33.23153075, 33.33332518, 33.37431145, 33.38610621, 33.39606091,
#        33.42757356, 33.50038678, 33.63087237, 33.83230281, 34.11511007,
#        34.48713196, 34.95384647, 35.51859437, 36.18279042, 36.94612348,
#        37.80674592, 38.76145256, 39.80584945, 40.93451292, 42.14113903,
#        43.41868385, 44.75949482, 46.15543347, 47.59798981, 49.07838864,
#        50.5876881 , 52.11687076, 53.65692736, 55.19893372, 56.73412084,
#        58.25393865, 59.75011345, 61.21469957, 62.64012518, 64.01923275,
#        65.34531428, 66.61214149, 67.81399139, 68.94566717, 70.00251495,
#        70.9804363 , 71.87589701, 72.68593213, 73.4081476 , 74.04071859,
#        74.58238482, 75.03244299, 75.39073659, 75.65764315, 75.83405923,
#        75.92138332, 75.92149668, 75.8367425 , 75.66990337, 75.42417733,
#        75.1031526 , 74.71078115, 74.25135129, 73.72945937, 73.1499808 ,
#        72.51804045, 71.83898264, 71.11834076, 70.36180676, 69.57520047,
#        68.76443905, 67.93550652, 67.09442362, 66.24721792, 65.39989453,
#        64.55840724, 63.72863038, 62.9163314 , 62.12714425, 61.36654368,
#        60.63982048, 59.95205782, 59.30810862, 58.71257415, 58.16978385,
#        57.68377642, 57.25828227, 56.89670731, 56.60211822, 56.37722911,
#        56.22438978, 56.1455754 , 56.14237781, 56.21599837, 56.36724241,
#        56.59651527, 56.90381999, 57.28875659, 57.75052297, 58.28791747,
#        58.89934302, 59.58281285, 60.33595787, 61.15603558, 62.03994048,
#        62.98421609, 63.98506842, 65.03838082, 66.13973038, 67.28440559,
#        68.46742537, 69.68355938, 70.92734949, 72.19313248, 73.47506378,
#        74.76714224, 76.06323588, 77.3571085 , 78.64244706, 79.91288982,
#        81.16205505, 82.38357033, 83.57110225, 84.7183864 , 85.81925772,
#        86.8676808 , 87.85778036, 88.78387144, 89.64048955, 90.42242031,
#        91.12472869, 91.7427876 , 92.27230574, 92.70935453, 93.05039407,
# 0.15124403779853424
# 0.22927286061622
# 0.30730471955710925
# 0.38493659494949384
# 0.4617663809365098
# 0.5373945059516387
# 0.6114255464949423
# 0.6834698302060218
# 0.7531450240781083
# 0.8200777037498739
# 0.883904899877777
# 0.944275617372611
# 1.000852323425761
# 1.0533124004679735
# 1.1013495596587148
# 1.1446752109761746
# 1.1830197859123643
# 1.2161340086427543
# 1.2437901112182743
# 1.2657829895472332
# 1.2819312950485795
# 1.2920784588693408
# 1.2960936436801802
# 1.2938726198020447
# 1.2853385609538464
# 1.2704427557897873
# 1.2491652313255344
# 1.2215152837525523
# 1.1875319127497477
# 1.147284155651775
# 1.100871316398127
# 1.0484230862204527
# 0.9900995513080773
# 0.926091083643783
# 0.8566181110417546
# 0.781930761571175
# 0.702308379879085
# 0.6180589091086119
# 0.5295181364275408
# 0.4370487968442376
# 0.341039531327084
# 0.24190369616778185
# 0.140078017454627
# 0.03602108942874338
# 0.06978829057651126
# 0.17685295170186066
# 0.28465934984870955
# 0.3926797419847645
# 0.5003745379091527
# 0.6071948352609837
# 0.7125851396152996
# 0.8159862762129961
# 0.9168384947630841
# 1.014584773905625
# 1.1086743279358728
# 1.1985663198104248
# 1.2837337853370343
# 1.3636677721397774
# 1.4378816978178577
# 1.5059159302295768
# 1.5673425962150844
# 1.6217706202015023
# 1.6688509987373834
# 1.7082823147063237
# 1.739816494329716
# 1.763264811098935
# 1.778504143611002
# 1.7854834864751723
# 1.7842307221407623
# 1.7748596568085304
# 1.7575773240058226
# 1.732691559704719
# 1.7006188541497664
# 1.6618924835899378
# 1.6171709263099245
# 1.5672465673038403
# 1.5130546937158016
# 1.4556827904505525
# 1.3963801316428786
# 1.336567680098561
# 1.2778482953846364
# 1.2220172522573662
# 1.1710730789547483
# 1.1272287140675132
# 1.0929229909274198
# 1.0708324485550804
# 1.0638834773435661
# 1.0752648022705102
# 1.1084403063869814
# 1.1671622012800782
# 1.255484545586178
# 1.3777771173947144
# 1.5387396459111713
# 1.7434164034637334
# 1.9972111627735032
# 2.305902527130449
# 2.675659630026324
# 3.113058218527442
# 3.6250971135373007
# 4.219215060151633
# 4.903307966064329

# %%
plt.plot(labels, dataset)

# %%
import math
import random
import time

# %%
def intensive_computation():
    result = 0
    for _ in range(10**6):
        result += math.sqrt(random.random())
    return result

# %%
while True:
    interval = 0.2 + 0.1 * math.sin(time.time() * 2 * math.pi / 60)  # Smooth fluctuation using sine function
    intensive_computation()
    time.sleep(interval)

# %%
for _ in range(10):
    interval = 0.2 + 0.1 * math.sin(time.time() * 2 * math.pi / 60)  # Smooth fluctuation using sine function
    print(interval)
    time.sleep(interval)
# Out:
# 0.2724760754978952
# 0.27047835933433506
# 0.26843805301946055
# 0.26635872137565286
# 0.2642432109836298
# 0.2620952969782991
# 0.2599177397522642
# 0.25771365527682366
# 0.25548569695587786
# 0.25323669628759166

# %%
time.time()
# Out:
# 1698324438.791201

# %%
math.sin(time.time() * 2 * math.pi / 60)
# Out:
# 0.5885468013102156

# %%
sin_data = []

n = 500
frequency = 0.5
oscillation = 4
buffer = 0.3

for x in range(n):
    value = (0.2 * math.sin((time.time() + x) * frequency * math.pi / 60) + buffer) * oscillation
    sin_data.append(value)
    
plt.plot([x for x in range(len(sin_data))], sin_data)

# %%
sin_data
# Out:
# [0.373997441857906,
#  0.37618905081515414,
#  0.37853404450102734,
#  0.3810308192531635,
#  0.38367766610128795,
#  0.38647276801577923,
#  0.38941421169503704,
#  0.39249997864773706,
#  0.3957279584932372,
#  0.39909593440311925,
#  0.4026015999318421,
#  0.4062425535264298,
#  0.41001629887939867,
#  0.41392024739395916,
#  0.41795172794099933,
#  0.42210797655846594,
#  0.4263861411592585,
#  0.4307832933013544,
#  0.4352964181941184,
#  0.43992242143296884,
#  0.4446581338542212,
#  0.4495003098369554,
#  0.4544456336389445,
#  0.45949071035283234,
#  0.46463208512060794,
#  0.46986623730553756,
#  0.4751895737229347,
#  0.48059844897684256,
#  0.4860891560941353,
#  0.4916579352093576,
#  0.4973009634203215,
#  0.503014376424943,
#  0.5087942601891089,
#  0.5146366535217765,
#  0.5205375456361229,
#  0.5264929024260999,
#  0.5324986322212699,
#  0.5385506275154599,
#  0.5446447354264727,
#  0.5507767845731314,
#  0.5569425653749133,
#  0.5631378573601845,
#  0.5693584092854892,
#  0.5755999667523267,
#  0.5818582414540392,
#  0.5881289531763747,
#  0.5944078007263144,
#  0.6006904791045624,
#  0.6069726842628959,
#  0.6132501124768752,
#  0.6195184579377309,
#  0.6257734281995387,
#  0.632010734630034,
#  0.6382261042535906,
#  0.6444152703116929,
#  0.6505739998737213,
#  0.6566980667832831,
#  0.6627832791195833,
#  0.6688254577419906,
#  0.6748204702558409,
#  0.6807642045247051,
#  0.6866525853399448,
#  0.6924815787982805,
#  0.698247191629986,
#  0.703945469090308,
#  0.7095725106961461,
#  0.7151244519798033,
#  0.7205974973931697,
#  0.72598788816323,
#  0.7312919331231735,
#  0.7365059971453252,
#  0.7416265082140588,
#  0.7466499554878189,
#  0.7515728961446196,
#  0.7563919562447331,
#  0.7611038317176223,
#  0.7657052946654236,
#  0.7701931927358674,
#  0.7745644488204717,
#  0.7788160658841228,
#  0.7829451313414584,
#  0.7869488175797275,
#  0.7908243761148254,
#  0.7945691531471463,
#  0.798180582193425,
#  0.8016561900995939,
#  0.8049935909011904,
#  0.8081904993274228,
#  0.8112447269229275,
#  0.8141541744504096,
#  0.8169168530096634,
#  0.8195308667776189,
#  0.8219944257264583,
#  0.8243058400537083,
#  0.8264635269459976,
#  0.8284660069520503,
#  0.8303119076712387,
#  0.8319999635567914,
#  0.8335290182471303,
#  0.8348980241712315,
#  0.8361060426223984,
#  0.8371522454099656,
#  0.8380359161137997,
#  0.838756448607166,
#  0.8393133494828673,
#  0.83970623675188,
#  0.8399348413723388,
#  0.8399990065347914,
#  0.8398986883155647,
#  0.8396339553119803,
#  0.8392049894055948,
#  0.8386120840481539,
#  0.8378556460235695,
#  0.836936193326476,
#  0.8358543566271655,
#  0.8346108767472088,
#  0.8332066061909421,
#  0.8316425078436335,
#  0.8299196532834152,
#  0.82803922326881,
#  0.8260025053492107,
#  0.823810897707815,
#  0.8214659012481978,
#  0.422108161968352,
#  0.4263863318648363,
#  0.4307834891719252,
#  0.4352966190954422,
#  0.43992262722735664,
#  0.44465834576368013,
#  0.44950052777684696,
#  0.4544458532533509,
#  0.4594909342769948,
#  0.46463231615418243,
#  0.4698664678835097,
#  0.4751898096442814,
#  0.4805986885774187,
#  0.48608940235752374,
#  0.4916581816733545,
#  0.49730121306380404,
#  0.5030146307124509,
#  0.50879451733021,
#  0.5146369083266118,
#  0.5205378079538793,
#  0.5264931653611673,
#  0.5324988989966867,
#  0.5385508979747228,
#  0.544645011148118,
#  0.5507770584108708,
#  0.5569428423800525,
#  0.5631381338258293,
#  0.5693586903283026,
#  0.5756002450881037,
#  0.5818585240050806,
#  0.5881292344053353,
#  0.5944080822234771,
#  0.600690760677003,
#  0.6069729692924077,
#  0.6132503936210252,
#  0.6195187403608217,
#  0.6257737081448014,
#  0.6320110172321483,
#  0.6382263804673421,
#  0.6444155487787702,
#  0.6505742768726522,
#  0.656698343861751,
#  0.662783549162092,
#  0.6688257292021099,
#  0.6748207394957827]

# %%
def generate_cooldown(bonus=0):

    # STATIC VARS
    frequency = 0.5
    oscillation = 4
    buffer = 0.3

    # FETCH SIN-WAVE COOLDOWN
    return (0.2 * math.sin((time.time() + bonus) * frequency * math.pi / 60) + buffer) * oscillation

# %%
generate_cooldown()
# Out:
# 1.9993084376455792

# %%
def cooldown_sim(n=500):
    sin_data = []

    for b in range(n):
        value = generate_cooldown(b)
        sin_data.append(value)
        
    print('N:\t', len(sin_data))
    print('MIN:\t', min(sin_data))
    print('MAX:\t', max(sin_data))
    
    plt.plot([x for x in range(len(sin_data))], sin_data)

# %%
cooldown_sim()
# Out:
# N:	 500
# MIN:	 0.4000003263371693
# MAX:	 1.9999996731957128

# %%
import time

# %%
last = time.time()

for number in range(1, 16):
    symbol = ''
    
    if 0 <= number <= 5:
        time.sleep(2)
        symbol = '---'
        
    if 6 <= number <= 10:
        time.sleep(1)
        symbol = '--'
        
    if 11 <= number <= 15:
        time.sleep(0.5)
        symbol = '-'
        
    ts = time.time()
    print(symbol, '\t', ts-last)
    last = ts
# Out:
# --- 	 2.0017507076263428
# --- 	 2.0011887550354004
# --- 	 2.002108097076416
# --- 	 2.0007717609405518
# --- 	 2.001422882080078
# -- 	 1.0000996589660645
# -- 	 1.001096248626709
# -- 	 1.0002689361572266
# -- 	 1.0009827613830566
# -- 	 1.0001208782196045
# - 	 0.500302791595459
# - 	 0.5006535053253174
# - 	 0.5006036758422852
# - 	 0.500605583190918
# - 	 0.5005991458892822

# %%
def generate_sine_wave(amp_min, amp_max):

    # Generate timestamps from 0 to 1 with a step of 0.01
    labels = np.arange(0, 2, 0.01)

    # Generate a sinusoidal wave between 0.2 and 3
    frequency = 1 # Adjust the frequency of the wave
    sine_wave = ((amp_max - amp_min) / 2) * np.sin(2 * np.pi * frequency * labels) + ((amp_max + amp_min) / 2)

    print(sum(sine_wave))
    
    # Plot the sinusoidal wave
    plt.plot(labels, sine_wave, label="Sinusoidal Wave")

# %%
generate_sine_wave(0.2, 3)
# Out:
# 320.0000000000002
